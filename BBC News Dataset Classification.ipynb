# %%
import pandas as pd
import os

data_folder = "BBC Dataset"
classes = ["business","entertainment","politics","sport","tech"]
x = []
y = []

for i in classes:
    files = os.listdir(i)
    for text_file in files:
        file_path = i + "/" +text_file
        with open(file_path) as f:
            data = f.readlines()
        data = ' '.join(data)
        x.append(data)
        y.append(i)
   
data = {'content': x, 'class': y}       
df = pd.DataFrame(data)
df.to_csv('bbc_news_data_5_classes.csv', index=False)

# %%
df_news = pd.read_csv("bbc_news_data_5_classes.csv")

# %%
df_news
# Out:
#                                                 content     class
# 0     Ad sales boost Time Warner profit\n \n Quarter...  business
# 1     Dollar gains on Greenspan speech\n \n The doll...  business
# 2     Yukos unit buyer faces loan claim\n \n The own...  business
# 3     High fuel prices hit BA's profits\n \n British...  business
# 4     Pernod takeover talk lifts Domecq\n \n Shares ...  business
# 5     Japan narrowly escapes recession\n \n Japan's ...  business
# 6     Jobs growth still slow in the US\n \n The US c...  business
# 7     India calls for fair trade rules\n \n India, w...  business
# 8     Ethiopia's crop production up 24%\n \n Ethiopi...  business
# 9     Court rejects $280bn tobacco case\n \n A US go...  business
# 10    Ask Jeeves tips online ad revival\n \n Ask Jee...  business
# 11    Indonesians face fuel price rise\n \n Indonesi...  business
# 12    Peugeot deal boosts Mitsubishi\n \n Struggling...  business
# 13    Telegraph newspapers axe 90 jobs\n \n The Dail...  business
# 14    Air passengers win new EU rights\n \n Air pass...  business
# 15    China keeps tight rein on credit\n \n China's ...  business
# 16    Parmalat boasts doubled profits\n \n Parmalat,...  business
# 17    India's rupee hits five-year high\n \n India's...  business
# 18    India widens access to telecoms\n \n India has...  business
# 19    Call centre users 'lose patience'\n \n Custome...  business
# 20    Rank 'set to sell off film unit'\n \n Leisure ...  business
# 21    Sluggish economy hits German jobs\n \n The num...  business
# 22    Mixed signals from French economy\n \n The Fre...  business
# 23    US trade gap hits record in 2004\n \n The gap ...  business
# 24    Yukos loses US bankruptcy battle\n \n A judge ...  business
# 25    Safety alert as GM recalls cars\n \n The world...  business
# 26    Steel firm 'to cut' 45,000 jobs\n \n Mittal St...  business
# 27    Strong demand triggers oil rally\n \n Crude oi...  business
# 28    UK firm faces Venezuelan land row\n \n Venezue...  business
# 29    Soaring oil 'hits world economy'\n \n The soar...  business
# ...                                                 ...       ...
# 2195  Text message record smashed again\n \n UK mobi...      tech
# 2196  Software watching while you work\n \n Software...      tech
# 2197  Commodore finds new lease of life\n \n The onc...      tech
# 2198  Cabs collect mountain of mobiles\n \n Gadgets ...      tech
# 2199  T-Mobile bets on 'pocket office'\n \n T-Mobile...      tech
# 2200  California sets fines for spyware\n \n The mak...      tech
# 2201  Mobile TV tipped as one to watch\n \n Scandina...      tech
# 2202  Apple laptop is 'greatest gadget'\n \n The App...      tech
# 2203  Sun offers processing by the hour\n \n Sun Mic...      tech
# 2204  Kenyan school turns to handhelds\n \n At the M...      tech
# 2205  Tough rules for ringtone sellers\n \n Firms th...      tech
# 2206  Mobile music challenges 'iPod age'\n \n Nokia ...      tech
# 2207  China 'ripe' for media explosion\n \n Asia is ...      tech
# 2208  Beckham virus spotted on the net\n \n Virus wr...      tech
# 2209  Video phones act as dating tools\n \n Technolo...      tech
# 2210  Progress on new internet domains\n \n By early...      tech
# 2211  Camera phones are 'must-haves'\n \n Four times...      tech
# 2212  Mobile multimedia slow to catch on\n \n There ...      tech
# 2213  Anti-spam laws bite spammer hard\n \n The net'...      tech
# 2214  Peer-to-peer nets 'here to stay'\n \n Peer-to-...      tech
# 2215  Broadband fuels online expression\n \n Fast we...      tech
# 2216  Savvy searchers fail to spot ads\n \n Internet...      tech
# 2217  TV's future down the phone line\n \n Internet ...      tech
# 2218  Cebit fever takes over Hanover\n \n Thousands ...      tech
# 2219  New consoles promise big problems\n \n Making ...      tech
# 2220  BT program to beat dialler scams\n \n BT is in...      tech
# 2221  Spam e-mails tempt net shoppers\n \n Computer ...      tech
# 2222  Be careful how you code\n \n A new European di...      tech
# 2223  US cyber security chief resigns\n \n The man m...      tech
# 2224  Losing yourself in online gaming\n \n Online r...      tech
#
# [2225 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import re
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import Word
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix


def clean_str(string):
    """
    Tokenization/string cleaning for datasets.
    Original taken from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
    """
    string = re.sub(r"\'s", "", string)
    string = re.sub(r"\'ve", "", string)
    string = re.sub(r"n\'t", "", string)
    string = re.sub(r"\'re", "", string)
    string = re.sub(r"\'d", "", string)
    string = re.sub(r"\'ll", "", string)
    string = re.sub(r",", "", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", "", string)
    string = re.sub(r"\)", "", string)
    string = re.sub(r"\?", "", string)
    string = re.sub(r"'", "", string)
    string = re.sub(r"[^A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"[0-9]\w+|[0-9]","", string)
    string = re.sub(r"\s{2,}", " ", string)
    return string.strip().lower()

data = pd.read_csv("bbc_news_data_5_classes.csv")
x = data['content'].tolist()
y = data['class'].tolist()

for index,value in enumerate(x):
    x[index] = ' '.join([Word(word).lemmatize() for word in clean_str(value).split()])

vect = TfidfVectorizer(stop_words='english',min_df=2)
X = vect.fit_transform(x)
Y = np.array(y)

# %%
X.shape
# Out:
# (2225, 14788)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (1780, 14788)
# (445, 14788)

# %%
model = RandomForestClassifier(n_estimators=400, max_depth=150,n_jobs=1)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=150, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=400, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array(['business', 'business', 'sport', 'business', 'politics', 'sport',
#        'sport', 'politics', 'sport', 'politics', 'business',
#        'entertainment', 'sport', 'business', 'entertainment', 'business',
#        'tech', 'entertainment', 'business', 'entertainment', 'business',
#        'sport', 'business', 'entertainment', 'business', 'sport',
#        'entertainment', 'sport', 'politics', 'sport', 'sport', 'politics',
#        'tech', 'entertainment', 'business', 'business', 'business',
#        'sport', 'tech', 'sport', 'tech', 'politics', 'business', 'sport',
#        'tech', 'tech', 'tech', 'business', 'business', 'tech',
#        'entertainment', 'business', 'politics', 'business',
#        'entertainment', 'politics', 'politics', 'politics', 'business',
#        'business', 'business', 'business', 'entertainment', 'business',
#        'sport', 'entertainment', 'business', 'business', 'politics',
#        'sport', 'politics', 'politics', 'tech', 'sport', 'business',
#        'sport', 'sport', 'entertainment', 'business', 'business', 'sport',
#        'sport', 'business', 'entertainment', 'entertainment', 'sport',
#        'sport', 'sport', 'entertainment', 'sport', 'sport', 'business',
#        'politics', 'business', 'sport', 'business', 'business',
#        'entertainment', 'business', 'politics', 'business', 'politics',
#        'business', 'business', 'sport', 'politics', 'sport', 'tech',
#        'entertainment', 'politics', 'business', 'tech', 'entertainment',
#        'business', 'politics', 'sport', 'entertainment', 'entertainment',
#        'entertainment', 'sport', 'politics', 'politics', 'business',
#        'politics', 'tech', 'business', 'tech', 'entertainment',
#        'business', 'entertainment', 'sport', 'entertainment',
#        'entertainment', 'sport', 'sport', 'politics', 'business',
#        'business', 'entertainment', 'tech', 'tech', 'business',
#        'politics', 'business', 'tech', 'entertainment', 'tech',
#        'business', 'business', 'politics', 'sport', 'entertainment',
#        'business', 'tech', 'tech', 'sport', 'sport', 'entertainment',
#        'business', 'entertainment', 'tech', 'entertainment', 'business',
#        'politics', 'tech', 'entertainment', 'business', 'tech', 'tech',
#        'politics', 'sport', 'sport', 'tech', 'entertainment', 'sport',
#        'tech', 'politics', 'politics', 'business', 'sport', 'politics',
#        'sport', 'business', 'politics', 'tech', 'sport', 'entertainment',
#        'sport', 'tech', 'business', 'business', 'sport', 'entertainment',
#        'tech', 'tech', 'entertainment', 'politics', 'politics', 'sport',
#        'tech', 'sport', 'entertainment', 'business', 'tech', 'business',
#        'politics', 'sport', 'politics', 'sport', 'sport', 'sport', 'tech',
#        'tech', 'entertainment', 'sport', 'politics', 'tech', 'tech',
#        'business', 'tech', 'business', 'business', 'business',
#        'entertainment', 'politics', 'politics', 'politics', 'politics',
#        'business', 'entertainment', 'sport', 'sport', 'entertainment',
#        'business', 'tech', 'sport', 'entertainment', 'business', 'tech',
#        'business', 'sport', 'business', 'politics', 'sport', 'business',
#        'business', 'business', 'business', 'sport', 'business',
#        'politics', 'sport', 'tech', 'business', 'entertainment', 'sport',
#        'entertainment', 'sport', 'sport', 'sport', 'politics', 'tech',
#        'business', 'entertainment', 'sport', 'business', 'politics',
#        'sport', 'business', 'politics', 'business', 'business',
#        'business', 'entertainment', 'business', 'sport', 'entertainment',
#        'politics', 'tech', 'business', 'business', 'tech', 'business',
#        'business', 'business', 'tech', 'politics', 'sport', 'business',
#        'tech', 'business', 'entertainment', 'business', 'entertainment',
#        'politics', 'business', 'business', 'tech', 'business', 'tech',
#        'sport', 'politics', 'tech', 'politics', 'sport', 'entertainment',
#        'business', 'politics', 'tech', 'business', 'sport', 'business',
#        'sport', 'tech', 'tech', 'tech', 'sport', 'business', 'sport',
#        'sport', 'politics', 'tech', 'tech', 'business', 'entertainment',
#        'business', 'business', 'tech', 'sport', 'politics', 'politics',
#        'business', 'sport', 'business', 'entertainment', 'sport',
#        'politics', 'politics', 'sport', 'politics', 'business', 'sport',
#        'tech', 'business', 'entertainment', 'business', 'sport',
#        'entertainment', 'sport', 'tech', 'tech', 'tech', 'entertainment',
#        'entertainment', 'politics', 'sport', 'entertainment', 'sport',
#        'tech', 'tech', 'politics', 'tech', 'business', 'sport', 'sport',
#        'tech', 'politics', 'politics', 'business', 'tech', 'business',
#        'sport', 'tech', 'politics', 'tech', 'business', 'politics',
#        'politics', 'sport', 'tech', 'politics', 'sport', 'entertainment',
#        'business', 'business', 'sport', 'business', 'tech', 'tech',
#        'entertainment', 'politics', 'tech', 'sport', 'sport', 'sport',
#        'entertainment', 'sport', 'sport', 'politics', 'business', 'tech',
#        'sport', 'entertainment', 'entertainment', 'politics', 'business',
#        'business', 'entertainment', 'tech', 'tech', 'tech',
#        'entertainment', 'tech', 'sport', 'sport', 'sport', 'business',
#        'politics', 'tech', 'politics', 'business', 'politics', 'business',
#        'politics', 'sport', 'business', 'entertainment', 'politics',
#        'politics', 'politics', 'sport', 'sport', 'entertainment', 'sport',
#        'sport', 'tech', 'tech', 'sport', 'sport', 'politics',
#        'entertainment', 'business', 'politics', 'entertainment',
#        'business'], dtype='<U13')

# %%
matrix = confusion_matrix(y_test,prediction)

# %%
matrix
# Out:
# array([[113,   0,   2,   0,   0],
#        [  2,  67,   2,   1,   0],
#        [  1,   0,  73,   1,   1],
#        [  1,   0,   0, 101,   0],
#        [  2,   1,   0,   1,  76]], dtype=int64)

# %%
acc = accuracy_score(y_test,prediction)

# %%
print("Accuracy-", acc)
# Out:
# Accuracy- 0.9662921348314607
